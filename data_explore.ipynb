# %%
import pandas as pd

# %%
df = pd.read_csv('data/Colleges_and_Universities.csv')
df = df.set_index('OBJECTID')

# %%
def candidate_finder(school_name, df):
    """Returns all schools with the SCHOOL_NAME in the title."""
    return df[[school_name.lower() in s.lower() for s in df['NAME']]]

candidate_finder('UNIVERSITY OF MICHIGAN', df)
# Out:
#           IPEDSID                              NAME                 ADDRESS  \
# OBJECTID
# 898        171137   UNIVERSITY OF MICHIGAN-DEARBORN       4901 EVERGREEN RD
# 1105       170976  UNIVERSITY OF MICHIGAN-ANN ARBOR     503 THOMPSON STREET
# 1369       171146      UNIVERSITY OF MICHIGAN-FLINT  303 E. KEARSLEY STREET
#
#                CITY STATE    ZIP           ZIP4       TELEPHONE  TYPE STATUS  \
# OBJECTID
# 898        DEARBORN    MI  48128           1491  (313) 593-5000     1      A
# 1105      ANN ARBOR    MI  48109  NOT AVAILABLE  (734) 764-1817     1      A
# 1369          FLINT    MI  48502           1950  (810) 762-3000     1      A
#
#           ...                                              ALIAS SIZE_SET  \
# OBJECTID  ...
# 898       ...                                               UM-D       12
# 1105      ...  U OF MICHIGAN|U OF M|UNIV OF MICHIGAN|U MICHIG...       16
# 1369      ...                                           UM-FLINT       12
#
# ...

# %%
teams_and_ids = {
    'AIR FORCE': 5959,
    'AKRON': 3133,
    'ALABAMA': 3001,
    'APPALACHIAN ST.': 1180,
    'ARIZONA': 2761,
    'ARIZONA ST.': 3445,
    'ARKANSAS': 3449,
    'ARKANSAS ST.': 5894,
    'ARMY': 1300,
    'AUBURN': 5207,
    'BALL ST.': 3561,
    'BAYLOR': 3584,
    'BOISE ST.': 3990,
    'BOSTON COLLEGE': 3244,
    'BOWLING GREEN': 3138,
    'BUFFALO': 325,
    'BYU': 5733,
    'CALIFORNIA': 3368,
    'CENTRAL MICHIGAN UNIVERSITY': 4208,
    'CHARLOTTE': 1252,
    'CINCINNATI': 2739,
    'CLEMSON': 3303,
    'COASTAL CAROLINA': 3329,
    'COLORADO': 5948,
    'COLORADO ST.': 484,
    'DUKE': 5030,
    'EAST CAROLINA': 6383,
    'EASTERN MICHIGAN': 3248,
    'FIU': 2527,
    'FAU': 4964,
    'FLORIDA': 2528,
    'FLORIDA ST.': 4123,
    'FRESNO ST.': 5905,
    'GEORIGA SOUTHERN': 5646,
    'GEORGIA': 1682,
    'GEORGIA ST.': 3984,
    'GEORIGA TECH': 2565,
    'HAWAII': 1364,
    'HOUSTON': 3713,
    'ILLINOIS': 5990,
    'INDIANA': 4606,
    'IOWA': 4023,
    'IOWA ST.': 4700,
    'KANSAS': 2586,
