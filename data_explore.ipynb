# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/jon_ross/Downloads/Colleges_and_Universities.csv')
df = df.set_index('OBJECTID')
df.head()
# Out:
#           IPEDSID                                       NAME  \
# OBJECTID
# 1          163204  UNIVERSITY OF MARYLAND-UNIVERSITY COLLEGE
# 2          192554                     LIU HUDSON AT ROCKLAND
# 3          187620       NEW MEXICO STATE UNIVERSITY-DONA ANA
# 4          188137                 SANTA FE COMMUNITY COLLEGE
# 5          189556          BRYANT & STRATTON COLLEGE-AMHERST
#
#                              ADDRESS        CITY STATE    ZIP           ZIP4  \
# OBJECTID
# 1          3501 UNIVERSITY BLVD EAST     ADELPHI    MD  20783           8010
# 2                       70 ROUTE 340  ORANGEBURG    NY  10962  NOT AVAILABLE
# 3         2800 N. SONOMA RANCH BLVD.  LAS CRUCES    NM  88011  NOT AVAILABLE
# 4                  6401 RICHARDS AVE    SANTA FE    NM  87508           4887
# 5           3650 MILLERSPORT HIGHWAY   GETZVILLE    NY  14068  NOT AVAILABLE
#
#                TELEPHONE  TYPE STATUS  ...          ALIAS SIZE_SET INST_SIZE  \
# ...

# %%
df[df.index == 5959]
# Out:
#           IPEDSID                             NAME  \
# OBJECTID
# 5959       128328  UNITED STATES AIR FORCE ACADEMY
#
#                                ADDRESS          CITY STATE    ZIP  ZIP4  \
# OBJECTID
# 5959      2304 CADET DRIVE, SUITE 3800  USAF ACADEMY    CO  80840  5002
#
#                TELEPHONE  TYPE STATUS  ...          ALIAS SIZE_SET INST_SIZE  \
# OBJECTID                               ...
# 5959      (719) 333-1818     1      A  ...  NOT AVAILABLE       14         2
#
#          PT_ENROLL  FT_ENROLL  TOT_ENROLL  HOUSING DORM_CAP TOT_EMP  \
# OBJECTID
# 5959          -999       4276        4276        1     4500     292
#
#              SHELTER_ID
# OBJECTID
# 5959      NOT AVAILABLE
#
# [1 rows x 42 columns]

# %%
teams_and_ids = {
    
}

# %%
# df.iloc[0]
sum(df['TOT_ENROLL'] > 1000)
# Out:
# 2591

# %%
len(df)
# Out:
# 7150

# %%
df[df['NAME'] == 'AIR FORCE']
# Out:
# Empty DataFrame
# Columns: [OBJECTID, IPEDSID, NAME, ADDRESS, CITY, STATE, ZIP, ZIP4, TELEPHONE, TYPE, STATUS, POPULATION, COUNTY, COUNTYFIPS, COUNTRY, LATITUDE, LONGITUDE, NAICS_CODE, NAICS_DESC, SOURCE, SOURCEDATE, VAL_METHOD, VAL_DATE, WEBSITE, STFIPS, COFIPS, SECTOR, LEVEL_, HI_OFFER, DEG_GRANT, LOCALE, CLOSE_DATE, MERGE_ID, ALIAS, SIZE_SET, INST_SIZE, PT_ENROLL, FT_ENROLL, TOT_ENROLL, HOUSING, DORM_CAP, TOT_EMP, SHELTER_ID]
# Index: []
#
# [0 rows x 43 columns]
